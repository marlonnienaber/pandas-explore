# %%
import sys
import os
sys.path.insert(0, os.path.abspath(".."))

import pandas as pd
import numpy as np
import math
from source.source import explore_numerical_attribute

# %% [markdown]
# **1) only numerical entiries**
# The function should display that the column contains only numerical values

# %%
data = {
    'column': list(range(1, 51)) + [1.0, 3.3337, 76.4657, 34.1]
}

df = pd.DataFrame(data)

explore_numerical_attribute(df["column"])
# Out:
# <div style='display: flex; flex-wrap: wrap;'>
#             <div style='margin: 10px; padding: 10px; border: 1px solid #ccc; text-align: left;'>
#                 <h4>Notes</h4>
#                 <ul style='list-style-type: none; padding: 0; margin: 0; text-align: left;'><li style='margin: 5px 0;'>- contains only valid numbers</li><li style='margin: 5px 0;'>- valid number entries contain ints and floats</li><li style='margin: 5px 0;'>- mean: 25.739</li><li style='margin: 5px 0;'>- median: 25.5</li><li style='margin: 5px 0;'>- standard deviation: 16.353</li><li style='margin: 5px 0;'>- range: [1.0,76.466]</li></ul>
#             </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
#                     <img src='data:image/png;base64,...' style='display: block; margin: 0 auto;'>
#                 </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
# ...

# %% [markdown]
# **2) display non-number entries**
# The function should display containen non-numbers and their occurence counts

# %%
data = {
    'column': list(range(1, 51)) + [1.0, 3.3337, 76.4657, 34.1] + 
    [np.nan, np.inf, -np.inf, "a", "a", None, math.nan, math.inf, -math.inf]
}

df = pd.DataFrame(data)

explore_numerical_attribute(df["column"])
# Out:
# <div style='display: flex; flex-wrap: wrap;'>
#             <div style='margin: 10px; padding: 10px; border: 1px solid #ccc; text-align: left;'>
#                 <h4>Notes</h4>
#                 <ul style='list-style-type: none; padding: 0; margin: 0; text-align: left;'><li style='margin: 5px 0;'>- valid number entries contain ints and floats</li><li style='margin: 5px 0;'>- mean: 25.739</li><li style='margin: 5px 0;'>- median: 25.5</li><li style='margin: 5px 0;'>- standard deviation: 16.353</li><li style='margin: 5px 0;'>- range: [1,76.466]</li></ul>
#             </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
#                     <img src='data:image/png;base64,...' style='display: block; margin: 0 auto;'>
#                 </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
#                     <img src='data:image/png;base64,...' style='display: block; margin: 0 auto;'>
# ...

# %%
# Generate 50 integers
int_values = [random.randint(-100, 100) for _ in range(100)]

# Generate 50 floats
float_values = [random.uniform(-100.0, 100.0) for _ in range(50)]

# Generate 15 atypical values
atypical_values = [
    np.nan, np.inf, -np.inf, 
    #"hello", None, "123", "NaN", "Infinity", "test",
    #0.0, -5, "apple", "banana", "cat", 3.14
]

# Combine all values into one collection
all_values = int_values + float_values + atypical_values

# Randomly sample 100 elements from the combined collection
sampled_data = random.choices(all_values, k=100)

# Create a DataFrame for the test data
test_data = pd.DataFrame({'Numerical': sampled_data})
explore_numerical_attribute(test_data['Numerical'])
# Out:
# <div style='display: flex; flex-wrap: wrap;'>
#             <div style='margin: 10px; padding: 10px; border: 1px solid #ccc; text-align: left;'>
#                 <h4>Notes</h4>
#                 <ul style='list-style-type: none; padding: 0; margin: 0; text-align: left;'><li style='margin: 5px 0;'>- valid number entries contain ints and floats</li><li style='margin: 5px 0;'>- mean: -7.439</li><li style='margin: 5px 0;'>- median: -20.0</li><li style='margin: 5px 0;'>- standard deviation: 52.956</li><li style='margin: 5px 0;'>- range: [-96.005,98.0]</li></ul>
#             </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
#                     <img src='data:image/png;base64,...' style='display: block; margin: 0 auto;'>
#                 </div>
#
#                 <div style='margin: 10px; padding: 10px; border: 1px solid #ccc;'>
#                     <img src='data:image/png;base64,...' style='display: block; margin: 0 auto;'>
# ...
